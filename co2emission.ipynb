# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\archive (4)\CO2 Emissions_Canada.csv")

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.drop(['Make', 'Model','Vehicle Class','Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)'],axis=1,inplace=True)
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Hwy (L/100 km)  \
# 0                2.0          4                              6.7
# 1                2.4          4                              7.7
# 2                1.5          4                              5.8
# 3                3.5          6                              9.1
# 4                3.5          6                              8.7
# ...              ...        ...                              ...
# 7380             2.0          4                              7.7
# 7381             2.0          4                              8.3
# 7382             2.0          4                              8.6
# 7383             2.0          4                              8.3
# 7384             2.0          4                              8.7
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 0                                  8.5                           33
# ...

# %%
df.drop(['Fuel Consumption Comb (L/100 km)','Fuel Consumption Comb (mpg)'],axis=1,inplace=True)
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Hwy (L/100 km)  \
# 0                2.0          4                              6.7
# 1                2.4          4                              7.7
# 2                1.5          4                              5.8
# 3                3.5          6                              9.1
# 4                3.5          6                              8.7
# ...              ...        ...                              ...
# 7380             2.0          4                              7.7
# 7381             2.0          4                              8.3
# 7382             2.0          4                              8.6
# 7383             2.0          4                              8.3
# 7384             2.0          4                              8.7
#
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...

# %%
m=sns.lmplot(x="Engine Size(L)",y="CO2 Emissions(g/km)", data=df, line_kws={'color':'red'})

# %%
x_bar=df["Engine Size(L)"].mean()
y_bar=df["CO2 Emissions(g/km)"].mean()
y_bar
# Out:
# np.float64(250.58469871360867)

# %%
df["numerator"]=(df["Engine Size(L)"]-x_bar)*(df["CO2 Emissions(g/km)"]-y_bar)

# %%
df["denominator"]=(df["Engine Size(L)"])**2
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption Hwy (L/100 km)  \
# 0                2.0          4                              6.7
# 1                2.4          4                              7.7
# 2                1.5          4                              5.8
# 3                3.5          6                              9.1
# 4                3.5          6                              8.7
# ...              ...        ...                              ...
# 7380             2.0          4                              7.7
# 7381             2.0          4                              8.3
# 7382             2.0          4                              8.6
# 7383             2.0          4                              8.3
# 7384             2.0          4                              8.7
#
#       CO2 Emissions(g/km)   numerator  denominator
# 0                     196   63.321946         4.00
# 1                     221   22.486374         5.76
# ...

# %%
theta1=df['numerator'].sum()/df['denominator'].sum()
theta1
# Out:
# np.float64(5.705144803216719)

# %%
theta0=y_bar-(theta1*x_bar)
theta0
# Out:
# np.float64(232.5560548697158)
